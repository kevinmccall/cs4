# %%
print('hello jupyter')
# Out:
# hello jupyter

# %%
import pandas as pd
import numpy as np


dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__deprecated_num_index_names',
#  '__dir__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_config',
#  '_is_numpy_dev',
#  '_libs',
#  '_testing',
#  '_typing',
#  '_version',
#  'annotations',
#  'api',
#  'array',
#  'arrays',
#  'bdate_range',
#  'compat',
#  'concat',
#  'core',
#  'crosstab',
#  'cut',
#  'date_range',
#  'describe_option',
#  'errors',
#  'eval',
#  'factorize',
#  'from_dummies',
#  'get_dummies',
#  'get_option',
#  'infer_freq',
#  'interval_range',
#  'io',
#  'isna',
#  'isnull',
#  'json_normalize',
#  'lreshape',
#  'melt',
#  'merge',
#  'merge_asof',
#  'merge_ordered',
#  'notna',
#  'notnull',
#  'offsets',
#  'option_context',
#  'options',
#  'pandas',
#  'period_range',
#  'pivot',
#  'pivot_table',
#  'plotting',
#  'qcut',
#  'read_clipboard',
#  'read_csv',
#  'read_excel',
#  'read_feather',
#  'read_fwf',
#  'read_gbq',
#  'read_hdf',
#  'read_html',
#  'read_json',
#  'read_orc',
#  'read_parquet',
#  'read_pickle',
#  'read_sas',
#  'read_spss',
#  'read_sql',
#  'read_sql_query',
#  'read_sql_table',
#  'read_stata',
#  'read_table',
#  'read_xml',
#  'reset_option',
#  'set_eng_float_format',
#  'set_option',
#  'show_versions',
#  'test',
#  'testing',
#  'timedelta_range',
#  'to_datetime',
#  'to_numeric',
#  'to_pickle',
#  'to_timedelta',
#  'tseries',
#  'unique',
#  'util',
#  'value_counts',
#  'wide_to_long']

# %%
from pydoc import ModuleScanner
import warnings

def scan_modules():
    """Scans for available modules using pydoc.ModuleScanner, taken from help('modules')"""
    modules = {}
    def callback(path, modname, desc, modules=modules):
        if modname and modname[-9:] == ".__init__":
            modname = modname[:-9] + " (package)"
        if modname.find(".") < 0:
            modules[modname] = 1
    def onerror(modname):
        callback(None, modname, None)
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")  # ignore warnings from importing deprecated modules
        ModuleScanner().run(callback, onerror=onerror)
    return modules

modules = list(scan_modules().keys())
print(sorted(modules))
# Out:
# ['15puzzle', 'IPython', 'OpenSSL', 'PIL', 'PyQt5', 'TBB', '__future__', '_abc', '_aix_support', '_argon2_cffi_bindings', '_ast', '_asyncio', '_bisect', '_black_version', '_blake2', '_bootsubprocess', '_bz2', '_cffi_backend', '_codecs', '_codecs_cn', '_codecs_hk', '_codecs_iso2022', '_codecs_jp', '_codecs_kr', '_codecs_tw', '_collections', '_collections_abc', '_compat_pickle', '_compression', '_contextvars', '_csv', '_ctypes', '_ctypes_test', '_datetime', '_decimal', '_distutils_hack', '_elementtree', '_functools', '_hashlib', '_heapq', '_imp', '_io', '_json', '_locale', '_lsprof', '_lzma', '_markupbase', '_md5', '_msi', '_multibytecodec', '_multiprocessing', '_nsis', '_opcode', '_operator', '_osx_support', '_overlapped', '_pickle', '_plotly_future_', '_plotly_utils', '_py_abc', '_pydecimal', '_pyio', '_pyrsistent_version', '_pytest', '_queue', '_random', '_ruamel_yaml', '_sha1', '_sha256', '_sha3', '_sha512', '_signal', '_sitebuiltins', '_socket', '_sqlite3', '_sre', '_ssl', '_stat', '_statistics', '_string', '_strptime', '_struct', '_symtable', '_system_path', '_testbuffer', '_testcapi', '_testconsole', '_testimportmultiple', '_testinternalcapi', '_testmultiphase', '_thread', '_threading_local', '_tkinter', '_tracemalloc', '_uuid', '_warnings', '_weakref', '_weakrefset', '_win32sysloader', '_winapi', '_winxptheme', '_xxsubinterpreters', '_yaml', '_zoneinfo', 'abc', 'adodbapi', 'afxres', 'aifc', 'alabaster', 'anaconda_navigator', 'anaconda_project', 'antigravity', 'anyio', 'appdirs', 'argon2', 'argparse', 'array', 'arrow', 'ast', 'astroid', 'astropy', 'asttokens', 'asynchat', 'asyncio', 'asyncore', 'atexit', 'atomicwrites', 'attr', 'attrs', 'audioop', 'automat', 'autopep8', 'babel', 'backcall', 'backports', 'base64', 'bcrypt', 'bdb', 'binaryornot', 'binascii', 'binhex', 'binstar_client', 'bisect', 'black', 'blackd', 'bleach', 'blib2to3', 'bokeh', 'boltons', 'bottleneck', 'brotli', 'bs4', 'builtins', 'bz2', 'cProfile', 'caffe2', 'calendar', 'certifi', 'cffi', 'cgi', 'cgitb', 'chardet', 'charset_normalizer', 'chunk', 'click', 'cloudpickle', 'clyent', 'cmath', 'cmd', 'code', 'codecs', 'codeop', 'collections', 'colorama', 'colorcet', 'colorsys', 'comm', 'commctrl', 'compileall', 'concurrent', 'conda', 'conda_build', 'conda_content_trust', 'conda_env', 'conda_pack', 'conda_package_handling', 'conda_package_streaming', 'conda_token', 'conda_verify', 'conf', 'configparser', 'constantly', 'contextlib', 'contextvars', 'contourpy', 'cookiecutter', 'copy', 'copyreg', 'crypt', 'cryptography', 'cssselect', 'csv', 'ctypes', 'curl', 'curses', 'cwp', 'cycler', 'cytoolz', 'daal4py', 'dask', 'dataclasses', 'datashader', 'datashape', 'datetime', 'dateutil', 'dbi', 'dbm', 'dde', 'debugpy', 'decimal', 'decorator', 'defusedxml', 'diff_match_patch', 'difflib', 'dill', 'dis', 'distributed', 'distutils', 'docstring_to_markdown', 'doctest', 'docutils', 'email', 'encodings', 'ensurepip', 'entrypoints', 'enum', 'erfa', 'errno', 'et_xmlfile', 'executing', 'fastjsonschema', 'faulthandler', 'filecmp', 'fileinput', 'filelock', 'flake8', 'flask', 'flit_core', 'fnmatch', 'fontTools', 'fractions', 'fsspec', 'ftplib', 'functools', 'future', 'gc', 'genericpath', 'gensim', 'getopt', 'getpass', 'gettext', 'glob', 'glob2', 'graphlib', 'greenlet', 'gzip', 'h5py', 'hamcrest', 'hashlib', 'heapdict', 'heapq', 'hmac', 'holoviews', 'html', 'http', 'huggingface_hub', 'hvplot', 'hyperlink', 'idlelib', 'idna', 'imagecodecs', 'imageio', 'imagesize', 'imaplib', 'imblearn', 'imghdr', 'imp', 'importlib', 'importlib_metadata', 'incremental', 'inflection', 'iniconfig', 'inspect', 'intake', 'intervaltree', 'io', 'ipaddress', 'ipykernel', 'ipykernel_launcher', 'ipython_genutils', 'ipywidgets', 'isapi', 'isort', 'isympy', 'itemadapter', 'itemloaders', 'itertools', 'itsdangerous', 'jedi', 'jellyfish', 'jinja2', 'jinja2_time', 'jmespath', 'joblib', 'json', 'json5', 'jsonpatch', 'jsonpointer', 'jsonschema', 'jupyter', 'jupyter_client', 'jupyter_console', 'jupyter_core', 'jupyter_server' ...

# %%
import pkgutil
a = list(pkgutil.iter_modules())
for x in a:
    print(f"Name: {x[1]}, is_module: {x[2]}")
# Out:
# Name: conf, is_module: False
# Name: sphinxify, is_module: False
# Name: sphinxthread, is_module: False
# Name: 15puzzle, is_module: False
# Name: _asyncio, is_module: False
# Name: _bz2, is_module: False
# Name: _ctypes, is_module: False
# Name: _ctypes_test, is_module: False
# Name: _decimal, is_module: False
# Name: _elementtree, is_module: False
# Name: _hashlib, is_module: False
# Name: _lzma, is_module: False
# Name: _msi, is_module: False
# Name: _multiprocessing, is_module: False
# Name: _overlapped, is_module: False
# Name: _queue, is_module: False
# Name: _socket, is_module: False
# Name: _sqlite3, is_module: False
# Name: _ssl, is_module: False
# Name: _testbuffer, is_module: False
# Name: _testcapi, is_module: False
# Name: _testconsole, is_module: False
# Name: _testimportmultiple, is_module: False
# Name: _testinternalcapi, is_module: False
# Name: _testmultiphase, is_module: False
# Name: _tkinter, is_module: False
# Name: _uuid, is_module: False
# Name: _zoneinfo, is_module: False
# Name: pyexpat, is_module: False
# Name: select, is_module: False
# Name: unicodedata, is_module: False
# Name: winsound, is_module: False
# Name: xxlimited, is_module: False
# Name: xxlimited_35, is_module: False
# Name: __future__, is_module: False
# Name: _aix_support, is_module: False
# Name: _bootsubprocess, is_module: False
# Name: _collections_abc, is_module: False
# Name: _compat_pickle, is_module: False
# Name: _compression, is_module: False
# Name: _markupbase, is_module: False
# Name: _nsis, is_module: False
# Name: _osx_support, is_module: False
# Name: _py_abc, is_module: False
# Name: _pydecimal, is_module: False
# Name: _pyio, is_module: False
# Name: _sitebuiltins, is_module: False
# Name: _strptime, is_module: False
# Name: _system_path, is_module: False
# Name: _threading_local, is_module: False
# Name: _weakrefset, is_module: False
# Name: abc, is_module: False
# Name: aifc, is_module: False
# Name: antigravity, is_module: False
# Name: argparse, is_module: False
# Name: ast, is_module: False
# Name: asynchat, is_module: False
# Name: asyncio, is_module: True
# Name: asyncore, is_module: False
# Name: base64, is_module: False
# Name: bdb, is_module: False
# Name: binhex, is_module: False
# Name: bisect, is_module: False
# Name: bz2, is_module: False
# Name: cProfile, is_module: False
# Name: calendar, is_module: False
# Name: cgi, is_module: False
# Name: cgitb, is_module: False
# Name: chunk, is_module: False
# Name: cmd, is_module: False
# Name: code, is_module: False
# Name: codecs, is_module: False
# Name: codeop, is_module: False
# Name: collections, is_module: True
# Name: colorsys, is_module: False
# Name: compileall, is_module: False
# Name: concurrent, is_module: True
# Name: configparser, is_module: False
# Name: contextlib, is_module: False
# Name: contextvars, is_module: False
# Name: copy, is_module: False
# Name: copyreg, is_module: False
# Name: crypt, is_module: False
# Name: csv, is_module: False
# Name: ctypes, is_module: True
# Name: curses, is_module: True
# Name: dataclasses, is_module: False
# Name: datetime, is_module: False
# Name: dbm, is_module: True
# Name: decimal, is_module: False
# Name: difflib, is_module: False
# Name: dis, is_module: False
# Name: distutils, is_module: True
# Name: doctest, is_module: False
# Name: email, is_module: True
# Name: encodings, is_module: True
# Name: ensurepip, is_module: True
# Name: enum, is_module: False
# Name: filecmp, is_module: False
# Name: fileinput, is_module: False
# Name: fnmatch, is_module: False
# Name: fractions, is_module: False
# Name: ftplib, is_module: False
# Name: functools, is_module: False
# Name: genericpath, is_module: False
# Name: getopt, is_module: False
# Name: getpass, is_module: False
# Name: gettext, is_module: False
# Name: glob, is_module: False
# Name: graphlib, is_module: False
# Name: gzip, is_module: False
# Name: hashlib, is_module: False
# Name: heapq, is_module: False
# Name: hmac, is_module: False
# Name: html, is_module: True
# Name: http, is_module: True
# Name: idlelib, is_module: True
# Name: imaplib, is_module: False
# Name: imghdr, is_module: False
# Name: imp, is_module: False
# Name: importlib, is_module: True
# Name: inspect, is_module: False
# Name: io, is_module: False
# Name: ipaddress, is_module: False
# Name: json, is_module: True
# Name: keyword, is_module: False
# Name: lib2to3, is_module: True
# Name: linecache, is_module: False
# Name: locale, is_module: False
# Name: logging, is_module: True
# Name: lzma, is_module: False
# Name: mailbox, is_module: False
# Name: mailcap, is_module: False
# Name: mimetypes, is_module: False
# Name: modulefinder, is_module: False
# Name: msilib, is_module: True
# Name: multiprocessing, is_module: True
# Name: netrc, is_module: False
# Name: nntplib, is_module: False
# Name: ntpath, is_module: False
# Name: nturl2path, is_module: False
# Name: numbers, is_module: False
# Name: opcode, is_module: False
# Name: operator, is_module: False
# Name: optparse, is_module: False
# Name: os, is_module: False
# Name: pathlib, is_module: False
# Name: pdb, is_module: False
# Name: pickle, is_module: False
# Name: pickletools, is_module: False
# Name: pipes, is_module: False
# Name: pkgutil, is_module: False
# Name: platform, is_module: False
# Name: plistlib, is_module: False
# Name: poplib, is_module: False
# Name: posixpath, is_module: False
# Name: pprint, is_module: False
# Name: profile, is_module: False
# Name: pstats, is_module: False
# Name: pty, is_module: False
# Name: py_compile, is_module: False
# Name: pyclbr, is_module: False
# Name: pydoc, is_module: False
# Name: pydoc_data, is_module: True
# Name: queue, is_module: False
# Name: quopri, is_module: False
# Name: random, is_module: False
# Name: re, is_module: False
# Name: reprlib, is_module: False
# Name: rlcompleter, is_module: False
# Name: runpy, is_module: False
# Name: sched, is_module: False
# Name: secrets, is_module: False
# Name: selectors, is_module: False
# Name: shelve, is_module: False
# Name: shlex, is_module: False
# Name: shutil, is_module: False
# Name: signal, is_module: False
# Name: site, is_module: False
# Name: smtpd, is_module: False
# Name: smtplib, is_module: False
# Name: sndhdr, is_module: False
# Name: socket, is_module: False
# Name: socketserver, is_module: False
# Name: sqlite3, is_module: True
# Name: sre_compile, is_module: False
# Name: sre_constants, is_module: False
# Name: sre_parse, is_module: False
# Name: ssl, is_module: False
# Name: stat, is_module: False
# Name: statistics, is_module: False
# Name: string, is_module: False
# Name: stringprep, is_module: False
# Name: struct, is_module: False
# Name: subprocess, is_module: False
# Name: sunau, is_module: False
# Name: symtable, is_module: False
# Name: sysconfig, is_module: False
# Name: tabnanny, is_module: False
# Name: tarfile, is_module: False
# Name: telnetlib, is_module: False
# Name: tempfile, is_module: False
# Name: test, is_module: True
# Name: textwrap, is_module: False
# Name: this, is_module: False
# Name: threading, is_module: False
# Name: timeit, is_module: False
# Name: tkinter, is_module: True
# Name: token, is_module: False
# Name: tokenize, is_module: False
# Name: trace, is_module: False
# Name: traceback, is_module: False
# Name: tracemalloc, is_module: False
# Name: tty, is_module: False
# Name: turtle, is_module: False
# Name: turtledemo, is_module: True
# Name: types, is_module: False
# Name: typing, is_module: False
# Name: unittest, is_module: True
# Name: urllib, is_module: True
# Name: uu, is_module: False
# Name: uuid, is_module: False
# Name: venv, is_module: True
# Name: warnings, is_module: False
# Name: wave, is_module: False
# Name: weakref, is_module: False
# Name: webbrowser, is_module: False
# Name: wsgiref, is_module: True
# Name: xdrlib, is_module: False
# Name: xml, is_module: True
# Name: xmlrpc, is_module: True
# Name: zipapp, is_module: False
# Name: zipfile, is_module: False
# Name: zipimport, is_module: False
# Name: zoneinfo, is_module: True
# Name: cwp, is_module: False
# Name: IPython, is_module: True
# Name: OpenSSL, is_module: True
# Name: PIL, is_module: True
# Name: PyQt5, is_module: True
# Name: TBB, is_module: False
# Name: _argon2_cffi_bindings, is_module: True
# Name: _black_version, is_module: False
# Name: _cffi_backend, is_module: False
# Name: _distutils_hack, is_module: True
# Name: _plotly_future_, is_module: True
# Name: _plotly_utils, is_module: True
# Name: _pyrsistent_version, is_module: False
# Name: _pytest, is_module: True
# Name: _ruamel_yaml, is_module: False
# Name: _yaml, is_module: True
# Name: adodbapi, is_module: True
# Name: alabaster, is_module: True
# Name: anaconda_navigator, is_module: True
# Name: anaconda_project, is_module: True
# Name: anyio, is_module: True
# Name: appdirs, is_module: False
# Name: argon2, is_module: True
# Name: arrow, is_module: True
# Name: astroid, is_module: True
# Name: astropy, is_module: True
# Name: asttokens, is_module: True
# Name: atomicwrites, is_module: True
# Name: attr, is_module: True
# Name: attrs, is_module: True
# Name: automat, is_module: True
# Name: autopep8, is_module: False
# Name: babel, is_module: True
# Name: backcall, is_module: True
# Name: backports, is_module: True
# Name: bcrypt, is_module: True
# Name: binaryornot, is_module: True
# Name: binstar_client, is_module: True
# Name: black, is_module: True
# Name: blackd, is_module: True
# Name: bleach, is_module: True
# Name: blib2to3, is_module: True
# Name: bokeh, is_module: True
# Name: boltons, is_module: True
# Name: bottleneck, is_module: True
# Name: brotli, is_module: True
# Name: bs4, is_module: True
# Name: caffe2, is_module: True
# Name: certifi, is_module: True
# Name: cffi, is_module: True
# Name: chardet, is_module: True
# Name: charset_normalizer, is_module: True
# Name: click, is_module: True
# Name: cloudpickle, is_module: True
# Name: clyent, is_module: True
# Name: colorama, is_module: True
# Name: colorcet, is_module: True
# Name: comm, is_module: True
# Name: conda, is_module: True
# Name: conda_build, is_module: True
# Name: conda_content_trust, is_module: True
# Name: conda_env, is_module: True
# Name: conda_pack, is_module: True
# Name: conda_package_handling, is_module: True
# Name: conda_package_streaming, is_module: True
# Name: conda_token, is_module: True
# Name: conda_verify, is_module: True
# Name: constantly, is_module: True
# Name: contourpy, is_module: True
# Name: cookiecutter, is_module: True
# Name: cryptography, is_module: True
# Name: cssselect, is_module: True
# Name: curl, is_module: True
# Name: cycler, is_module: False
# Name: cytoolz, is_module: True
# Name: daal4py, is_module: True
# Name: dask, is_module: True
# Name: datashader, is_module: True
# Name: datashape, is_module: True
# Name: dateutil, is_module: True
# Name: debugpy, is_module: True
# Name: decorator, is_module: False
# Name: defusedxml, is_module: True
# Name: diff_match_patch, is_module: True
# Name: dill, is_module: True
# Name: distributed, is_module: True
# Name: docstring_to_markdown, is_module: True
# Name: docutils, is_module: True
# Name: entrypoints, is_module: False
# Name: erfa, is_module: True
# Name: et_xmlfile, is_module: True
# Name: executing, is_module: True
# Name: fastjsonschema, is_module: True
# Name: filelock, is_module: True
# Name: flake8, is_module: True
# Name: flask, is_module: True
# Name: flit_core, is_module: True
# Name: fontTools, is_module: True
# Name: fsspec, is_module: True
# Name: future, is_module: True
# Name: gensim, is_module: True
# Name: glob2, is_module: True
# Name: greenlet, is_module: True
# Name: h5py, is_module: True
# Name: hamcrest, is_module: True
# Name: heapdict, is_module: False
# Name: holoviews, is_module: True
# Name: huggingface_hub, is_module: True
# Name: hvplot, is_module: True
# Name: hyperlink, is_module: True
# Name: idna, is_module: True
# Name: imagecodecs, is_module: True
# Name: imageio, is_module: True
# Name: imagesize, is_module: True
# Name: imblearn, is_module: True
# Name: importlib_metadata, is_module: True
# Name: incremental, is_module: True
# Name: inflection, is_module: True
# Name: iniconfig, is_module: True
# Name: intake, is_module: True
# Name: intervaltree, is_module: True
# Name: ipykernel, is_module: True
# Name: ipykernel_launcher, is_module: False
# Name: ipython_genutils, is_module: True
# Name: ipywidgets, is_module: True
# Name: isapi, is_module: True
# Name: isort, is_module: True
# Name: isympy, is_module: False
# Name: itemadapter, is_module: True
# Name: itemloaders, is_module: True
# Name: itsdangerous, is_module: True
# Name: jedi, is_module: True
# Name: jellyfish, is_module: True
# Name: jinja2, is_module: True
# Name: jinja2_time, is_module: True
# Name: jmespath, is_module: True
# Name: joblib, is_module: True
# Name: json5, is_module: True
# Name: jsonpatch, is_module: False
# Name: jsonpointer, is_module: False
# Name: jsonschema, is_module: True
# Name: jupyter, is_module: False
# Name: jupyter_client, is_module: True
# Name: jupyter_console, is_module: True
# Name: jupyter_core, is_module: True
# Name: jupyter_server, is_module: True
# Name: jupyterlab, is_module: True
# Name: jupyterlab_plotly, is_module: True
# Name: jupyterlab_pygments, is_module: True
# Name: jupyterlab_server, is_module: True
# Name: jupyterlab_widgets, is_module: True
# Name: jwt, is_module: True
# Name: keyring, is_module: True
# Name: kiwisolver, is_module: True
# Name: lazy_object_proxy, is_module: True
# Name: libarchive, is_module: True
# Name: libfuturize, is_module: True
# Name: libpasteurize, is_module: True
# Name: lief, is_module: False
# Name: llvmlite, is_module: True
# Name: locket, is_module: True
# Name: lxml, is_module: True
# Name: lz4, is_module: True
# Name: markdown, is_module: True
# Name: markupsafe, is_module: True
# Name: matplotlib, is_module: True
# Name: matplotlib_inline, is_module: True
# Name: mccabe, is_module: False
# Name: menuinst, is_module: True
# Name: mistune, is_module: False
# Name: mkl, is_module: True
# Name: mkl_fft, is_module: True
# Name: mkl_random, is_module: True
# Name: mock, is_module: True
# Name: mpmath, is_module: True
# Name: msgpack, is_module: True
# Name: multipledispatch, is_module: True
# Name: munkres, is_module: False
# Name: mypy_extensions, is_module: False
# Name: nacl, is_module: True
# Name: navigator_updater, is_module: True
# Name: nbclassic, is_module: True
# Name: nbclient, is_module: True
# Name: nbconvert, is_module: True
# Name: nbformat, is_module: True
# Name: nest_asyncio, is_module: False
# Name: networkx, is_module: True
# Name: nltk, is_module: True
# Name: notebook, is_module: True
# Name: notebook_shim, is_module: True
# Name: numba, is_module: True
# Name: numbergen, is_module: True
# Name: numexpr, is_module: True
# Name: numpy, is_module: True
# Name: numpydoc, is_module: True
# Name: onedal, is_module: True
# Name: openpyxl, is_module: True
# Name: packaging, is_module: True
# Name: pandas, is_module: True
# Name: pandocfilters, is_module: False
# Name: panel, is_module: True
# Name: param, is_module: True
# Name: paramiko, is_module: True
# Name: parsel, is_module: True
# Name: parso, is_module: True
# Name: partd, is_module: True
# Name: past, is_module: True
# Name: pathspec, is_module: True
# Name: patsy, is_module: True
# Name: pep8, is_module: False
# Name: pexpect, is_module: True
# Name: pickleshare, is_module: False
# Name: pip, is_module: True
# Name: pkg_resources, is_module: True
# Name: pkginfo, is_module: True
# Name: platformdirs, is_module: True
# Name: plotly, is_module: True
# Name: pluggy, is_module: True
# Name: ply, is_module: True
# Name: pooch, is_module: True
# Name: poyo, is_module: True
# Name: prometheus_client, is_module: True
# Name: prompt_toolkit, is_module: True
# Name: protego, is_module: False
# Name: psutil, is_module: True
# Name: ptyprocess, is_module: True
# Name: pure_eval, is_module: True
# Name: pvectorc, is_module: False
# Name: py, is_module: True
# Name: pyasn1, is_module: True
# Name: pyasn1_modules, is_module: True
# Name: pycodestyle, is_module: False
# Name: pycosat, is_module: False
# Name: pycparser, is_module: True
# Name: pyct, is_module: True
# Name: pycurl, is_module: False
# Name: pydispatch, is_module: True
# Name: pydocstyle, is_module: True
# Name: pyflakes, is_module: True
# Name: pygments, is_module: True
# Name: pylab, is_module: False
# Name: pylint, is_module: True
# Name: pylint_venv, is_module: False
# Name: pyls_spyder, is_module: True
# Name: pylsp, is_module: True
# Name: pylsp_black, is_module: True
# Name: pylsp_jsonrpc, is_module: True
# Name: pyodbc, is_module: False
# Name: pyparsing, is_module: True
# Name: pyrsistent, is_module: True
# Name: pytest, is_module: True
# Name: pythoncom, is_module: False
# Name: pytoolconfig, is_module: True
# Name: pytz, is_module: True
# Name: pyviz_comms, is_module: True
# Name: pywt, is_module: True
# Name: qdarkstyle, is_module: True
# Name: qstylizer, is_module: True
# Name: qtawesome, is_module: True
# Name: qtconsole, is_module: True
# Name: qtpy, is_module: True
# Name: queuelib, is_module: True
# Name: regex, is_module: True
# Name: repo_cli, is_module: True
# Name: requests, is_module: True
# Name: requests_file, is_module: False
# Name: requests_toolbelt, is_module: True
# Name: rope, is_module: True
# Name: rtree, is_module: True
# Name: ruamel_yaml, is_module: True
# Name: scipy, is_module: True
# Name: scrapy, is_module: True
# Name: seaborn, is_module: True
# Name: send2trash, is_module: True
# Name: service_identity, is_module: True
# Name: setuptools, is_module: True
# Name: sipbuild, is_module: True
# Name: six, is_module: False
# Name: skimage, is_module: True
# Name: sklearn, is_module: True
# Name: sklearnex, is_module: True
# Name: slugify, is_module: True
# Name: smart_open, is_module: True
# Name: snappy, is_module: True
# Name: sniffio, is_module: True
# Name: snowballstemmer, is_module: True
# Name: socks, is_module: False
# Name: sockshandler, is_module: False
# Name: sortedcontainers, is_module: True
# Name: soupsieve, is_module: True
# Name: sphinx, is_module: True
# Name: spyder, is_module: True
# Name: spyder_kernels, is_module: True
# Name: sqlalchemy, is_module: True
# Name: stack_data, is_module: True
# Name: statsmodels, is_module: True
# Name: sympy, is_module: True
# Name: tables, is_module: True
# Name: tabulate, is_module: False
# Name: tbb, is_module: True
# Name: tblib, is_module: True
# Name: tenacity, is_module: True
# Name: terminado, is_module: True
# Name: test_pycosat, is_module: False
# Name: text_unidecode, is_module: True
# Name: textdistance, is_module: True
# Name: threadpoolctl, is_module: False
# Name: three_merge, is_module: True
# Name: tifffile, is_module: True
# Name: tinycss2, is_module: True
# Name: tldextract, is_module: True
# Name: tlz, is_module: True
# Name: tokenizers, is_module: True
# Name: toml, is_module: True
# Name: tomli, is_module: True
# Name: tomlkit, is_module: True
# Name: toolz, is_module: True
# Name: torch, is_module: True
# Name: torchgen, is_module: True
# Name: tornado, is_module: True
# Name: tqdm, is_module: True
# Name: traitlets, is_module: True
# Name: transformers, is_module: True
# Name: twisted, is_module: True
# Name: typing_extensions, is_module: False
# Name: ujson, is_module: False
# Name: unidecode, is_module: True
# Name: urllib3, is_module: True
# Name: w3lib, is_module: True
# Name: watchdog, is_module: True
# Name: wcwidth, is_module: True
# Name: webencodings, is_module: True
# Name: websocket, is_module: True
# Name: werkzeug, is_module: True
# Name: whatthepatch, is_module: True
# Name: wheel, is_module: True
# Name: widgetsnbextension, is_module: True
# Name: win32com, is_module: True
# Name: win32ctypes, is_module: True
# Name: win_inet_pton, is_module: False
# Name: wincertstore, is_module: False
# Name: winpty, is_module: True
# Name: wrapt, is_module: True
# Name: xarray, is_module: True
# Name: xlwings, is_module: True
# Name: yaml, is_module: True
# Name: yapf, is_module: True
# Name: yapftests, is_module: True
# Name: zict, is_module: True
# Name: zipp, is_module: True
# Name: zmq, is_module: True
# Name: zope, is_module: True
# Name: zstandard, is_module: True
# Name: _win32sysloader, is_module: False
# Name: _winxptheme, is_module: False
# Name: dde, is_module: False
# Name: mmapfile, is_module: False
# Name: odbc, is_module: False
# Name: perfmon, is_module: False
# Name: servicemanager, is_module: False
# Name: timer, is_module: False
# Name: win32api, is_module: False
# Name: win32clipboard, is_module: False
# Name: win32console, is_module: False
# Name: win32cred, is_module: False
# Name: win32crypt, is_module: False
# Name: win32event, is_module: False
# Name: win32evtlog, is_module: False
# Name: win32file, is_module: False
# Name: win32gui, is_module: False
# Name: win32help, is_module: False
# Name: win32inet, is_module: False
# Name: win32job, is_module: False
# Name: win32lz, is_module: False
# Name: win32net, is_module: False
# Name: win32pdh, is_module: False
# Name: win32pipe, is_module: False
# Name: win32print, is_module: False
# Name: win32process, is_module: False
# Name: win32profile, is_module: False
# Name: win32ras, is_module: False
# Name: win32security, is_module: False
# Name: win32service, is_module: False
# Name: win32trace, is_module: False
# Name: win32transaction, is_module: False
# Name: win32ts, is_module: False
# Name: win32ui, is_module: False
# Name: win32uiole, is_module: False
# Name: win32wnet, is_module: False
# Name: winxpgui, is_module: False
# Name: afxres, is_module: False
# Name: commctrl, is_module: False
# Name: dbi, is_module: False
# Name: mmsystem, is_module: False
# Name: netbios, is_module: False
# Name: ntsecuritycon, is_module: False
# Name: pywin32_bootstrap, is_module: False
# Name: pywin32_testutil, is_module: False
# Name: pywintypes, is_module: False
# Name: rasutil, is_module: False
# Name: regcheck, is_module: False
# Name: regutil, is_module: False
# Name: sspi, is_module: False
# Name: sspicon, is_module: False
# Name: win2kras, is_module: False
# Name: win32con, is_module: False
# Name: win32cryptcon, is_module: False
# Name: win32evtlogutil, is_module: False
# Name: win32gui_struct, is_module: False
# Name: win32inetcon, is_module: False
# Name: win32netcon, is_module: False
# Name: win32pdhquery, is_module: False
# Name: win32pdhutil, is_module: False
# Name: win32rcparser, is_module: False
# Name: win32serviceutil, is_module: False
# Name: win32timezone, is_module: False
# Name: win32traceutil, is_module: False
# Name: win32verstamp, is_module: False
# Name: winerror, is_module: False
# Name: winioctlcon, is_module: False
# Name: winnt, is_module: False
# Name: winperf, is_module: False
# Name: winxptheme, is_module: False
# Name: pywin, is_module: True
